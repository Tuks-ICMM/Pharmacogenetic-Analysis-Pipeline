# %%
# Import libraries and init Matplotlib for inline graphs
# %matplotlib inline

import seaborn
import matplotlib
import pandas
import myvariant

# %%
data = pandas.read_excel("../data/Supplementary Table.xlsx", sheet_name=1)
data
# Out:
#           Variant              Location Allele   Existing_variation  \
# 0     rs529868340  19:40991207-40991207      A          rs529868340
# 1      rs34223104  19:40991224-40991224      C  rs34223104,CR050427
# 2     rs563558831  19:40991226-40991226      C          rs563558831
# 3     rs530873393  19:40991233-40991233      T          rs530873393
# 4     rs115178405  19:40991260-40991260      T          rs115178405
# ...           ...                   ...    ...                  ...
# 1337  rs111959737                   NaN    NaN                  NaN
# 1338  rs112856484                   NaN    NaN                  NaN
# 1339  rs113535769                   NaN    NaN                  NaN
# 1340  rs559715037                   NaN    NaN                  NaN
# 1341  rs560162669                   NaN    NaN                  NaN
#
#                 Consequence    Feature  SOURCE SIFT PolyPhen Condel  ...  \
# 0     upstream_gene_variant  NM_000767  RefSeq    -        -      -  ...
# ...

# %%
data["myVariant_lookup"] = "chr" + (data["Location"].str.split(":").str[0]) + ":g." + (data["Location"].str.split(":").str[1].str.split("-").str[0]) + ">" + data["Allele"]
data
# Out:
#          Variant              Location Allele   Existing_variation  \
# 0     rs72549453  19:40843438-40843438      C           rs72549453
# 1    rs146895354  19:40843446-40843446      G          rs146895354
# 2    rs569152950  19:40843552-40843552      A          rs569152950
# 3    rs192752442  19:40843567-40843567      G          rs192752442
# 4    rs558177610  19:40843603-40843603      T          rs558177610
# ..           ...                   ...    ...                  ...
# 391  rs201793905  19:40850453-40850453      T          rs201793905
# 392   rs28399433  19:40850474-40850474      C  rs28399433,CR015160
# 393  rs528755675  19:40850518-40850518      C          rs528755675
# 394  rs547290288  19:40850520-40850520      T          rs547290288
# 395  rs183167151  19:40850537-40850537      G          rs183167151
#
#                  Consequence    Feature  SOURCE SIFT PolyPhen Condel  ...  \
# 0    downstream_gene_variant  NM_000762  RefSeq    -        -      -  ...
# ...

# %%
mv = myvariant.MyVariantInfo()
for i in data["myVariant_lookup"]:
    mv.getvariant(i, fields="clinvar")
