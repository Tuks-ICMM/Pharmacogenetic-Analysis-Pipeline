# %% [markdown]
# %%latex
# \tableofcontents

# %% [markdown]
# # Introduction

# %% [markdown]
# Understanding the distribution of variants across population groups, and within population groups is needed to better understand population structure and any forces that may be shaping that structure. This notebook will describe patterns in variant frequency distribution across population groups. Statistical methods will be used to examine differences in frequency distribution between multiple subsets of mutations found, to identify variants of note.
#
# The data used in this notebook  is a valuable tool to identify patterns that are associated with biological function. Using these types of annotations, we describe clinically relevant variants and investigate their impact in greater detail.

# %% [markdown]
# > This notebook will import and make use of data that has already been filtered to identify variants of clinical interest. The criteria used are described in the first notebook of this series, which also describes the code used to perform the data.

# %% [markdown]
# ## Objectives
#
# This notebook will focus on the following objectives:

# %% [markdown]
# - To verify the distribution models that apply to the observed variant frequencies
# - To identify significant differences of variant frequency grouped by consequence type:
#     - between populations
#     - within populations
# - To identify significant differences of variant frequency grouped by exon:
#     - between populations
#     - within populations

# %% [markdown]
# ## Notebook Configuration

# %% [markdown]
# ### Dependencies
#
# This notebook will make use of the following python packages to perform the described analysis:

# %%
from pandas import read_csv, melt, to_numeric
from os.path import join
from statannotations.Annotator import Annotator
from itertools import combinations
from matplotlib.pyplot import (
    xlim,
    figure,
    subplots,
    subplots_adjust,
)
from seaborn import boxplot, move_legend, color_palette, set_theme
from scipy.stats import norm, normaltest
from statsmodels.graphics.gofplots import qqplot
from os.path import join
from pathlib import Path
from json import load

# %%
with open(join("config", "manifest.json"), 'r') as config:
    config = load(config)

path = join(*config["output"])

# %% [markdown]
# ### Data Imports

# %% [markdown]
# Before we start graphing, lets first set up some standard information that will be needed:

# %%
# [ASSIGN] the sample metadata used to conduct the analysis to a reference variable
SAMPLES = read_csv(join("input", "samples.csv"))

# [ASSIGN] the genomic location metadata used to conduct the analysis to a reference variable
LOCATIONS = read_csv(join("input", "locations.csv"))

# [ASSIGN] the dataset metadata used to conduct the analysis to a reference variable
DATASETS = read_csv(join("input", "datasets.csv"))

# [ASSIGN] a sorted list of all the unique population codes found in the annotations used in this analysis.
POPULATIONS_TO_COMPARE = sorted(SAMPLES["super-population"].unique().tolist())

# [ASSIGN] a sorted list of the genomic regions analyzed
LOCATIONS_COVERED = sorted(LOCATIONS["location_name"].unique().tolist())

# %% [markdown]
# Next, lets import the results, which are stored in the form of CSV files grouped by cluster annotations provided during the analysis. This notebook will focus on the analysis of the clusters annotated in the super-population group.

# %%
# [SET] a dictionary to be used to house our data, indexed by gene
DATA = dict()

# [FOR] each gene in our list of gene regions included in this analysis...
for gene in LOCATIONS_COVERED:
    # [ASSIGN] a DataFrame containing our imported gene-specific datasets to our DATA object
    DATA[gene] = read_csv(
        join(
            "/",
            "mnt",
            "ICMM_HDD_12TB",
            "Results_25SEP2024",
            "cleaned",
            f"super-population_{gene}.csv.zst",
        )
    )
    DATA[gene].rename(columns={
        "Consequence_type": "Consequence"
    }, inplace=True)

# %%
# [FOR] each gene in our list of gene regions analyzed
for gene in LOCATIONS_COVERED:
    # [ASSIGN] the replaced column of data
    DATA[gene]["Consequence"] = DATA[gene]["Consequence"].replace({
    "regulatory_region_variant": "Regulatory Region",
    "upstream_gene_variant": "Upstream",
    "splice_polypyrimidine_tract_variant": "Splice Polypyrimidine Tract",
    "synonymous_variant": "Synonymous",
    "3_prime_UTR_variant": "3' UTR",
    "5_prime_UTR_variant": "5' UTR",
    "intergenic_variant": "Intergenic",
    "splice_region_variant": "Splice Region",
    "intron_variant": "Intron",
    "stop_gained": "Stop-Gain",
    "splice_donor_region_variant": "Splice Doner Region",
    "missense_variant": "Missense",
    "splice_acceptor_variant": "Splice Acceptor",
    "non_coding_transcript_exon_variant": "Non-Coding Transcript Exon",
    "downstream_gene_variant": "Downstream Gene",
    "TF_binding_site_variant": "TF Binding Site",
})

# %% [markdown]
# ### Plot storage and configuration

# %% [markdown]
# To store our generated plots, we can use a python dictionary to store these in a hierarchical index, using the name of each gene region to order collections of related plots together. We can also make use of nested dictionaries to store multiple plot types for each gene.

# %%
# [STORE] of all plots we will be making.
PLOT = dict()

# [FOR] each gene, create a storage space for any plots generated (This should use a hierarchical storage structure of PLOT[gene][graph])
for gene in LOCATIONS_COVERED:

    # [ASSIGN] an empty dictionary to store all plots made for this gene
    PLOT[gene] = dict()

# [ASSIGN] a generic record to house plots that apply across genes
PLOT[None] = dict()

# %% [markdown]
# Lets also set a few theme options that will apply to all of our plots:

# %%
# [CREDIT] for ratio sizes goes to a Bio-render article I found which talks about plot sizes
# https://www.biorender.com/blog/why-layout-and-scale-matters-for-graphs
set_theme(rc={"figure.figsize": (10, 7)}, style="ticks", palette="hls")

# %% [markdown]
# # Allele Frequency Distribution

# %% [markdown]
# First, lets look at the distribution of observed allele frequencies. This can be done using the Seaborn plot, [`boxplot`](https://seaborn.pydata.org/generated/seaborn.boxplot.html). By investigating these distribution observed, we can identify statistically significant differences within and between our population groups. We can use the [statannotations](https://pypi.org/project/statannotations/) package to run and apply statistical annotations to our boxplots.

# %% [markdown]
# ## Q-Q plot with test for normality

# %% [markdown]
# In order to better understand the patterns in our data, lets start by visualizing the distribution of variant frequency across different grouping types. By visualizing our data in sets or groups, we can use statistics such as or derived from the Chi-Squared statistic to identify sets with significantly different distributions.
#
# For this task, we can use the python [`statannotations`](https://pypi.org/project/statannotations/) package which provides an interface to access statistical functions offered by the wll-known [`scipy`](https://scipy.org/) statistical package, and apply these to plots generated using [`seaborn`](https://seaborn.pydata.org/), another well-known python graphing library. This facility offers the use of the following scipy statistical functions:
#
# - [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) | Mann-Whitney test
# - [`ttest_ind`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind) & [`ttest_rel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html#ttest-rel) | t-test (independent and paired)
# - [`ttest_ind`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind) | Welch's t-test
# - [`levene`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html#levene) | Levene test
# - [`wilcoxon`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html#wilcoxon) | Wilcoxon test
# - [`kruskal`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kruskal.html#scipy.stats.kruskal) | Kruskal-Wallis test
# - [`brunnermunzel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.brunnermunzel.html#scipy.stats.brunnermunzel) | Brunner-Munzel test

# %% [markdown]
# The [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) method is ideal for our purposes since it is designed for unrelated samples. `Scipy.stats` does however note that in situations where the data being analyzed follows a normal-distribution, that a T-test would be more appropriate. Given this, we will first have to perform a test of distribution to determine if our data follows a normal distribution. For this, we can make use of the [`qqplot`](https://www.statsmodels.org/stable/generated/statsmodels.graphics.gofplots.qqplot.html) function from [`statsmodels`](https://www.statsmodels.org/stable/index.html).
#
# A Q-Q Plot is used to understand how well our data fits to known models of distribution, such as the famous normal distribution. This is done by plotting the theoretical quartiles on the x-axis and our observed quartiles on the y-axis. In this case, we will generate a regression-line to indicate the goodness-of-fit visually.

# %%
# [ASSIGN] the number of rows and columns to be made in this subplot
_nrows = len(LOCATIONS_COVERED)
_ncols = len(POPULATIONS_TO_COMPARE)

# [ASSIGN] the subplot figure and axes objects to variables for plotting and formatting
PLOT[None]["Q-Q Plot (Frequency)"], axes = subplots(
    _nrows,
    _ncols,
    sharex=True,
    sharey=True,
)

# [ASSIGN] a new plot title
PLOT[None]["Q-Q Plot (Frequency)"].suptitle("Q-Q Distribution Test | Normal Distribution")

# [ASSIGN] a new plot x-label
PLOT[None]["Q-Q Plot (Frequency)"].supxlabel("Theoretical Quantiles")

# [ASSIGN] a new plot y-label
PLOT[None]["Q-Q Plot (Frequency)"].supylabel("Sample Quantiles")

# [MUTATE] the subplot to add a bit more spacing between the plot and its X and Y axis labels
subplots_adjust(left=0.135, bottom=0.15)

# [FOR] each gene in our list of genes
for geneIndex, gene in enumerate(LOCATIONS_COVERED):
    # [FOR] each population in our list of population groups
    for populationIndex, population in enumerate(POPULATIONS_TO_COMPARE):
        # [ASSIGN] the results of the test for normality for later use
        isNormal = normaltest(DATA[gene][population])

        # [IF] the p-value from our normality-test is less-than or equal to 0.05, we can safely reject the null hypothesis:
        if isNormal.pvalue <= 0.05:
            # [MUTATE] set the sub-plot background color to indicate significance
            axes[geneIndex, populationIndex].set_facecolor("#ff000066")
        else:
            axes[geneIndex, populationIndex].set_facecolor("lightgray")

        # [PLOT] a Q-Q plot for a spesific gene-population pair to the apropriate sub-plot axes
        qqplot(
            DATA[gene][population],
            dist=norm,
            fit=True,
            line="r",
            ax=axes[geneIndex, populationIndex],
        )

        # [MUTATE] activate the grid on the plots for ease-of-reference
        axes[geneIndex, populationIndex].grid(True)
        
        # [MUTATE] remove the x-label from the individual sub-plot or there will be too much clutter
        axes[geneIndex, populationIndex].set_xlabel("")
        
        # [MUTATE] remove the y-label from the individual sub-plot or there will be too much clutter
        axes[geneIndex, populationIndex].set_ylabel("")
        
        # [MUTATE] rotate the label ticks and make them slightly smaller
        axes[geneIndex, populationIndex].tick_params(labelrotation=90, labelsize=7)

# [FOR] each gene in our list of genes
for geneIndex, gene in enumerate(LOCATIONS_COVERED):
    # [ASSIGN] a single set of y-labels (gene) to only the first column of the grid of plots
    axes[geneIndex, 0].set_ylabel(f"{gene}", rotation=65, size=8)

# [FOR] each population in our list of population groups
for populationIndex, population in enumerate(POPULATIONS_TO_COMPARE):
    # [ASSIGN] a single set of x-labels (population) to only the last row of the grid of plots
    axes[_nrows - 1, populationIndex].set_xlabel(f"{population}", size=8)
# Out:
# /home/students/miniconda3/envs/GRAEME_statannotations/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=13 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# As we can see from the above Q-Q plot, most of our gene-regions are noted with a significant p value. Although the data does show some degree of correlation, our normality test shows that there is a low probability of observing the frequencies found in the CYP2B6, CYP2C9, CYP2C19, CYP2D6, CYP4F2, HLA-A and HLA-B gene regions in a normally distributed dataset. Low-enough for us to confidently reject our null hypothesis that these frequency observations could have been sampled from a normally distributed population.
#
# Based on the above findings, it will not be advisable to use a T-test, as this type of test relies on the assumption of normality. For this reason, we will opt for using the Mann-Whitney U-test, provided via the [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) function.

# %% [markdown]
# # Frequency distribution by consequence type

# %% [markdown]
# Now lets take a closer look at our frequency distribution from before, but this time, lets separate the data into groups by consequence type.

# %% [markdown]
# ## within populations

# %%
# [FOR] gene in genes to be analyzed
for gene in LOCATIONS_COVERED:
    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Consequence"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [ASSIGN] a sorted list of exons to be analyzed
    consequences_found = sorted(TMP["Consequence"].unique().tolist())
    
    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["consequence_within"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        boxprops={'edgecolor': 'none'},
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["consequence_within"].get_xticks():
        PLOT[gene]["consequence_within"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")


    # [PLOT] set limits on the y-axis
    PLOT[gene]["consequence_within"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    consequence_combinations_within_populations = list()

    # [FOR] each combination of any two consequence types possible...
    for consequence_1, consequence_2 in combinations(consequences_found, 2):
        # [ASSIGN] a temporary variable to house all combinations for the above-two consequences
        _tmp = list()

        # [FOR] each population in our list of populations to be compared
        for population in POPULATIONS_TO_COMPARE:
            # [ASSIGN] a set of comparison expressions to compare these two consequences within our populations
            _tmp.append(
                (( population, consequence_1), (population, consequence_2)),
            )
        # [ASSIGN] the filter expressions generated for the above consequence-comparison across all populations into our tally variable
        consequence_combinations_within_populations.extend(_tmp)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["consequence_within"],
        consequence_combinations_within_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )

    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["consequence_within"].axhline(1.0, _x_min, _x_max, color="gray", linestyle="--")

    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["consequence_within"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["consequence_within"].figure.suptitle(
        f"Distribution of allele frequencies by consequence type (within populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["consequence_within"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# SAS_Missense vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.827e-06 U_stat=3.848e+04
# EAS_Upstream vs. EAS_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.140e-03 U_stat=2.683e+04
# AMR_Missense vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.284e-03 U_stat=4.430e+04
# EUR_Missense vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.349e-08 U_stat=3.582e+04
# EUR_Upstream vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.033e-03 U_stat=6.017e+04
# CSA_Intron vs. CSA_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.616e-06 U_stat=2.713e+05
# OCE_Intron vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.950e-06 U_stat=1.795e+05
# SAS_Intron vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.769e-02 U_stat=2.552e+05
# UAE_Intron vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.186e-03 U_stat=2.592e+05
# AFR_Intron vs. AFR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.222e-02 U_stat=2.577e+05
# SAS_Missense vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.006e-04 U_stat=9.336e+03
# AMR_Missense vs. AMR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.015e-05 U_stat=8.710e+03
# EUR_Missense vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.914e-09 U_stat=7.286e+03
# EUR_Intron vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.240e-03 U_stat=2.563e+05
# SAS_Missense vs. SAS_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.650e-04 U_stat=3.611e+03
# EUR_Missense vs. EUR_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.170e-04 U_stat=3.591e+03
# AFR_Intron vs. AFR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.291e-07 U_stat=2.678e+05
# SAS_Missense vs. SAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.119e-05 U_stat=8.570e+03
# EUR_Missense vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.726e-04 U_stat=9.150e+03
# AMR_Missense vs. AMR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.950e-03 U_stat=9.331e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# ## between populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Consequence"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population"
    )
     
    # [REPLACE] null values with "Non-Exon" for graphing purposes.
    TMP.fillna("Non-Exon", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [ASSIGN] a list of consequences to be analyzed
    consequences_found = sorted(TMP["Consequence"].unique().tolist())

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["consequence_between"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        boxprops={'edgecolor': 'none'}
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["consequence_between"].get_xticks():
        PLOT[gene]["consequence_between"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")
        
    # [PLOT] set limits on the y-axis
    PLOT[gene]["consequence_between"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    consequence_combinations_between_populations = list()
    
    # [FOR] each consequence type found...
    for consequence in TMP["Consequence"].unique().tolist():
        _tmp = list()
        # [FOR] each combination of any two consequence types possible...
        for population_1, population_2 in combinations(POPULATIONS_TO_COMPARE, 2):
            # [ASSIGN] a set of comparison expressions to compare these two consequences between our populations
            _tmp.extend([((population_1, consequence), (population_2, consequence))])
        
        # [ASSIGN] the filter expressions generated for the above consequence-comparison across all populations into our tally variable
        consequence_combinations_between_populations.extend(_tmp)

    # [SORT] these combinations and order them by exon, which will be our conditional-split/nested x-axis in this graph.
    print(consequence_combinations_between_populations)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["consequence_between"],
        consequence_combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        show_test_name=True
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )

    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["consequence_between"].axhline(1, _x_min, _x_max, c="gray", ls=":")

    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["consequence_between"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["consequence_between"].figure.suptitle(
        f"Distribution of allele frequencies by consequence type (between populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["consequence_between"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# [(('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EAS' ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# CSA_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.073e-03 U_stat=8.524e+03
# AFR_Intron vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.704e-02 U_stat=8.451e+03
# EAS_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.373e-02 U_stat=4.746e+03
# EUR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.028e-10 U_stat=9.733e+03
# OCE_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.072e-03 U_stat=4.956e+03
# AFR_Intron vs. CSA_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.059e-03 U_stat=8.740e+03
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.534e-08 U_stat=9.638e+03
# OCE_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.854e-09 U_stat=3.564e+03
# AFR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.616e-10 U_stat=1.004e+04
# CSA_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.390e-08 U_stat=9.501e+03
# AFR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.721e-06 U_stat=9.341e+03
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.101e-15 U_stat=1.064e+04
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.441e-03 U_stat=4.506e+03
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.349e-18 U_stat=1.096e+04
# AMR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.370e-03 U_stat=8.734e+03
# AFR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.129e-08 U_stat=9.825e+03
# AFR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.111e-03 U_stat=8.709e+03
# [(('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Stop-Gain'), ('AMR', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('CSA', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('CSA', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('OCE', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('OCE', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('SAS', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Intron vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.010e-08 U_stat=1.868e+05
# AFR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.579e-07 U_stat=1.858e+05
# AFR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.337e-09 U_stat=1.893e+05
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.349e-04 U_stat=1.775e+05
# AFR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.052e-04 U_stat=1.776e+05
# AFR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.889e-04 U_stat=1.785e+05
# [(('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('OCE', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('OCE', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('SAS', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'M ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.693e-03 U_stat=3.019e+04
# CSA_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.007e-05 U_stat=4.708e+04
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.374e-02 U_stat=4.471e+04
# EAS_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.953e-02 U_stat=3.057e+04
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.778e-05 U_stat=2.817e+04
# [(('AFR', "3' UTR"), ('AMR', "3' UTR")), (('AFR', "3' UTR"), ('CSA', "3' UTR")), (('AFR', "3' UTR"), ('EAS', "3' UTR")), (('AFR', "3' UTR"), ('EUR', "3' UTR")), (('AFR', "3' UTR"), ('OCE', "3' UTR")), (('AFR', "3' UTR"), ('SAS', "3' UTR")), (('AFR', "3' UTR"), ('UAE', "3' UTR")), (('AMR', "3' UTR"), ('CSA', "3' UTR")), (('AMR', "3' UTR"), ('EAS', "3' UTR")), (('AMR', "3' UTR"), ('EUR', "3' UTR")), (('AMR', "3' UTR"), ('OCE', "3' UTR")), (('AMR', "3' UTR"), ('SAS', "3' UTR")), (('AMR', "3' UTR"), ('UAE', "3' UTR")), (('CSA', "3' UTR"), ('EAS', "3' UTR")), (('CSA', "3' UTR"), ('EUR', "3' UTR")), (('CSA', "3' UTR"), ('OCE', "3' UTR")), (('CSA', "3' UTR"), ('SAS', "3' UTR")), (('CSA', "3' UTR"), ('UAE', "3' UTR")), (('EAS', "3' UTR"), ('EUR', "3' UTR")), (('EAS', "3' UTR"), ('OCE', "3' UTR")), (('EAS', "3' UTR"), ('SAS', "3' UTR")), (('EAS', "3' UTR"), ('UAE', "3' UTR")), (('EUR', "3' UTR"), ('OCE', "3' UTR")), (('EUR', "3' UTR"), ('SAS', "3' UTR")), (('EUR', "3' UTR"), ('UAE', "3' UTR")), (('OCE', "3' UTR"), ('SAS', "3' UTR")), (('OCE', "3' UTR"), ('UAE', "3' UTR")), (('SAS', "3' UTR"), ('UAE', "3' UTR")), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice  ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.548e-02 U_stat=4.010e+02
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.860e-04 U_stat=4.380e+02
# [(('AFR', "3' UTR"), ('AMR', "3' UTR")), (('AFR', "3' UTR"), ('CSA', "3' UTR")), (('AFR', "3' UTR"), ('EAS', "3' UTR")), (('AFR', "3' UTR"), ('EUR', "3' UTR")), (('AFR', "3' UTR"), ('OCE', "3' UTR")), (('AFR', "3' UTR"), ('SAS', "3' UTR")), (('AFR', "3' UTR"), ('UAE', "3' UTR")), (('AMR', "3' UTR"), ('CSA', "3' UTR")), (('AMR', "3' UTR"), ('EAS', "3' UTR")), (('AMR', "3' UTR"), ('EUR', "3' UTR")), (('AMR', "3' UTR"), ('OCE', "3' UTR")), (('AMR', "3' UTR"), ('SAS', "3' UTR")), (('AMR', "3' UTR"), ('UAE', "3' UTR")), (('CSA', "3' UTR"), ('EAS', "3' UTR")), (('CSA', "3' UTR"), ('EUR', "3' UTR")), (('CSA', "3' UTR"), ('OCE', "3' UTR")), (('CSA', "3' UTR"), ('SAS', "3' UTR")), (('CSA', "3' UTR"), ('UAE', "3' UTR")), (('EAS', "3' UTR"), ('EUR', "3' UTR")), (('EAS', "3' UTR"), ('OCE', "3' UTR")), (('EAS', "3' UTR"), ('SAS', "3' UTR")), (('EAS', "3' UTR"), ('UAE', "3' UTR")), (('EUR', "3' UTR"), ('OCE', "3' UTR")), (('EUR', "3' UTR"), ('SAS', "3' UTR")), (('EUR', "3' UTR"), ('UAE', "3' UTR")), (('OCE', "3' UTR"), ('SAS', "3' UTR")), (('OCE', "3' UTR"), ('UAE', "3' UTR")), (('SAS', "3' UTR"), ('UAE', "3' UTR")), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# CSA_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.917e-05 U_stat=1.162e+04
# AFR_Intron vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.256e-08 U_stat=1.252e+04
# SAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.333e-03 U_stat=6.107e+03
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.280e-08 U_stat=1.252e+04
# AFR_Intron vs. CSA_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.048e-05 U_stat=1.170e+04
# OCE_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.336e-02 U_stat=6.309e+03
# AFR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.001e-17 U_stat=1.412e+04
# CSA_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.132e-02 U_stat=1.078e+04
# AFR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.169e-06 U_stat=1.202e+04
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.583e-07 U_stat=1.206e+04
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.208e-05 U_stat=5.549e+03
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.883e-08 U_stat=1.239e+04
# AMR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.970e-03 U_stat=1.106e+04
# AFR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.167e-08 U_stat=1.255e+04
# AFR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.597e-04 U_stat=1.158e+04
# [(('AFR', 'Upstream'), ('AMR', 'Upstream')), (('AFR', 'Upstream'), ('CSA', 'Upstream')), (('AFR', 'Upstream'), ('EAS', 'Upstream')), (('AFR', 'Upstream'), ('EUR', 'Upstream')), (('AFR', 'Upstream'), ('OCE', 'Upstream')), (('AFR', 'Upstream'), ('SAS', 'Upstream')), (('AFR', 'Upstream'), ('UAE', 'Upstream')), (('AMR', 'Upstream'), ('CSA', 'Upstream')), (('AMR', 'Upstream'), ('EAS', 'Upstream')), (('AMR', 'Upstream'), ('EUR', 'Upstream')), (('AMR', 'Upstream'), ('OCE', 'Upstream')), (('AMR', 'Upstream'), ('SAS', 'Upstream')), (('AMR', 'Upstream'), ('UAE', 'Upstream')), (('CSA', 'Upstream'), ('EAS', 'Upstream')), (('CSA', 'Upstream'), ('EUR', 'Upstream')), (('CSA', 'Upstream'), ('OCE', 'Upstream')), (('CSA', 'Upstream'), ('SAS', 'Upstream')), (('CSA', 'Upstream'), ('UAE', 'Upstream')), (('EAS', 'Upstream'), ('EUR', 'Upstream')), (('EAS', 'Upstream'), ('OCE', 'Upstream')), (('EAS', 'Upstream'), ('SAS', 'Upstream')), (('EAS', 'Upstream'), ('UAE', 'Upstream')), (('EUR', 'Upstream'), ('OCE', 'Upstream')), (('EUR', 'Upstream'), ('SAS', 'Upstream')), (('EUR', 'Upstream'), ('UAE', 'Upstream')), (('OCE', 'Upstream'), ('SAS', 'Upstream')), (('OCE', 'Upstream'), ('UAE', 'Upstream')), (('SAS', 'Upstream'), ('UAE', 'Upstream')), (('AFR', "5' UTR"), ('AMR', "5' UTR")), (('AFR', "5' UTR"), ('CSA', "5' UTR")), (('AFR', "5' UTR"), ('EAS', "5' UTR")), (('AFR', "5' UTR"), ('EUR', "5' UTR")), (('AFR', "5' UTR"), ('OCE', "5' UTR")), (('AFR', "5' UTR"), ('SAS', "5' UTR")), (('AFR', "5' UTR"), ('UAE', "5' UTR")), (('AMR', "5' UTR"), ('CSA', "5' UTR")), (('AMR', "5' UTR"), ('EAS', "5' UTR")), (('AMR', "5' UTR"), ('EUR', "5' UTR")), (('AMR', "5' UTR"), ('OCE', "5' UTR")), (('AMR', "5' UTR"), ('SAS', "5' UTR")), (('AMR', "5' UTR"), ('UAE', "5' UTR")), (('CSA', "5' UTR"), ('EAS', "5' UTR")), (('CSA', "5' UTR"), ('EUR', "5' UTR")), (('CSA', "5' UTR"), ('OCE', "5' UTR")), (('CSA', "5' UTR"), ('SAS', "5' UTR")), (('CSA', "5' UTR"), ('UAE', "5' UTR")), (('EAS', "5' UTR"), ('EUR', "5' UTR")), (('EAS', "5' UTR"), ('OCE', "5' UTR")), (('EAS', "5' UTR"), ('SAS', "5' UTR")), (('EAS', "5' UTR"), ('UAE', "5' UTR")), (('EUR', "5' UTR"), ('OCE', "5' UTR")), (('EUR', "5' UTR"), ('SAS', "5' UTR")), (('EUR', "5' UTR"), ('UAE', "5' UTR")), (('OCE', "5' UTR"), ('SAS', "5' UTR")), (('OCE', "5' UTR"), ('UAE', "5' UTR")), (('SAS', "5' UTR"), ('UAE', "5' UTR")), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_3' UTR vs. OCE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.102e-03 U_stat=9.900e+01
# EUR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.402e-03 U_stat=6.355e+02
# CSA_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.496e-03 U_stat=1.894e+03
# CSA_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.007e-03 U_stat=7.154e+03
# CSA_3' UTR vs. EUR_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.777e-02 U_stat=5.190e+02
# AMR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.396e-02 U_stat=6.912e+03
# EUR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.095e-04 U_stat=3.063e+03
# EUR_3' UTR vs. UAE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.631e-02 U_stat=1.110e+02
# AFR_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.581e-03 U_stat=1.894e+03
# AFR_3' UTR vs. EUR_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.277e-02 U_stat=5.230e+02
# AMR_3' UTR vs. OCE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.080e-03 U_stat=8.400e+01
# AFR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.735e-03 U_stat=1.846e+03
# [(('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice  ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Upstream vs. CSA_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.632e-07 U_stat=6.555e+04
# EUR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.381e-09 U_stat=1.122e+06
# OCE_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.388e-10 U_stat=8.243e+05
# AFR_Upstream vs. AMR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.900e-12 U_stat=3.295e+04
# EAS_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.018e-02 U_stat=4.146e+04
# EUR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.735e-07 U_stat=3.723e+04
# OCE_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.108e-09 U_stat=6.720e+04
# AFR_Downstream Gene vs. AMR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.247e-04 U_stat=3.774e+04
# CSA_Upstream vs. EAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.455e-03 U_stat=4.114e+04
# CSA_Missense vs. EUR_Missense: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.076e-03 U_stat=5.446e+03
# EAS_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.547e-10 U_stat=1.133e+06
# OCE_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.002e-14 U_stat=8.023e+05
# AMR_Upstream vs. EAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.843e-02 U_stat=6.062e+04
# CSA_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.359e-05 U_stat=3.862e+04
# EAS_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.441e-03 U_stat=4.075e+04
# EUR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.573e-04 U_stat=6.238e+04
# OCE_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.304e-06 U_stat=6.491e+04
# AFR_Downstream Gene vs. CSA_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.244e-03 U_stat=3.898e+04
# AMR_Downstream Gene vs. EAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.057e-03 U_stat=5.902e+04
# AMR_Downstream Gene vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.183e-03 U_stat=5.900e+04
# CSA_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.092e-17 U_stat=1.170e+06
# AFR_Upstream vs. EAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.717e-06 U_stat=3.794e+04
# CSA_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.085e-05 U_stat=3.833e+04
# EUR_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.043e-05 U_stat=6.412e+04
# AFR_Missense vs. EUR_Missense: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.739e-02 U_stat=5.204e+03
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.331e-15 U_stat=1.163e+06
# AFR_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.727e-10 U_stat=3.432e+04
# AMR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.087e-04 U_stat=3.959e+04
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.540e-11 U_stat=1.137e+06
# AFR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.243e-10 U_stat=3.426e+04
# AMR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.744e-08 U_stat=6.625e+04
# AMR_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.586e-07 U_stat=6.556e+04
# AFR_Downstream Gene vs. SAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.287e-03 U_stat=3.898e+04
# [(('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Upstream'), ('AMR', 'Upstream')), (('AFR', 'Upstream'), ('CSA', 'Upstream')), (('AFR', 'Upstream'), ('EAS', 'Upstream')), (('AFR', 'Upstream'), ('EUR', 'Upstream')), (('AFR', 'Upstream'), ('OCE', 'Upstream')), (('AFR', 'Upstream'), ('SAS', 'Upstream')), (('AFR', 'Upstream'), ('UAE', 'Upstream')), (('AMR', 'Upstream'), ('CSA', 'Upstream')), (('AMR', 'Upstream'), ('EAS', 'Upstream')), (('AMR', 'Upstream'), ('EUR', 'Upstream')), (('AMR', 'Upstream'), ('OCE', 'Upstream')), (('AMR', 'Upstream'), ('SAS', 'Upstream')), (('AMR', 'Upstream'), ('UAE', 'Upstream')), (('CSA', 'Upstream'), ('EAS', 'Upstream')), (('CSA', 'Upstream'), ('EUR', 'Upstream')), (('CSA', 'Upstream'), ('OCE', 'Upstream')), (('CSA', 'Upstream'), ('SAS', 'Upstream')), (('CSA', 'Upstream'), ('UAE', 'Upstream')), (('EAS', 'Upstream'), ('EUR', 'Upstream')), (('EAS', 'Upstream'), ('OCE', 'Upstream')), (('EAS', 'Upstream'), ('SAS', 'Upstream')), (('EAS', 'Upstream'), ('UAE', 'Upstream')), (('EUR', 'Upstream'), ('OCE', 'Upstream')), (('EUR', 'Upstream'), ('SAS', 'Upstream')), (('EUR', 'Upstream'), ('UAE', 'Upstream')), (('OCE', 'Upstream'), ('SAS', 'Upstream')), (('OCE', 'Upstream'), ('UAE', 'Upstream')), (('SAS', 'Upstream'), ('UAE', 'Upstream'))]
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# # Frequency distribution by exon

# %% [markdown]
# Lets take a closer look at our frequency distribution like before> For this set, lets separate the data into groups by exon.

# %% [markdown]
# ## within populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Exon"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [ASSIGN] filler text for any variants which do not have an exon annotation
    TMP.fillna("Non-Exon", inplace=True)

    # [ASSIGN] a numeric sorting key, constructed using the numerator in the fraction-based exon labeling system
    TMP["Exon Sorting Key"] = TMP["Exon"].str.split("/", expand=True)[0]

    # [ASSIGN] the correct numerical sorting key for non-exon mutations which did not use the fraction-based exon labeling system
    TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)

    # [ASSIGN] cast the column to a numeric type, to ensure no data-type confusion when plotting
    TMP["Exon Sorting Key"] = to_numeric(TMP["Exon Sorting Key"])

    # [SORT] the TMP DataFrame by the newly created sorting key
    TMP.sort_values(by="Exon Sorting Key", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["exon_within"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        hue_order=sorted(TMP["Exon"].unique().tolist()),
        boxprops={'edgecolor': 'none'}
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["exon_within"].get_xticks():
        PLOT[gene]["exon_within"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")

    # [ASSIGN] a list of exons to be analysed
    exons_found = TMP["Exon"].unique().tolist()

    # [PLOT] set limits on the y-axis
    PLOT[gene]["exon_within"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    combinations_between_populations = list()

    # [FOR] each combination of any two consequence types possible...
    for exon_1, exon_2 in combinations(exons_found, 2):
        # [ASSIGN] a temporary variable to house all combinations for the above-two exons
        _tmp = list()

        # [FOR] each population in our list of populations to be compared
        for population in POPULATIONS_TO_COMPARE:
            # [ASSIGN] a set of comparison expressions to compare these two exons within our populations
            _tmp.extend([((population, exon_1), (population, exon_2))])

        # [ASSIGN] the filter expressions generated for the above exon-comparison across all populations into our tally variable
        combinations_between_populations.extend(_tmp)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["exon_within"],
        combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        order=POPULATIONS_TO_COMPARE,
        hue_order=sorted(exons_found),
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )
    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["exon_within"].axhline(1, _x_min, _x_max, c="gray", ls=":")

    # [PLOT] a label for the abovementioned horizontal line
    PLOT[gene]["exon_within"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["exon_within"].figure.suptitle(
        f"Distribution of allele frequencies by exon (within populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["exon_within"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# SAS_4/8 vs. SAS_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.199e-03 U_stat=6.000e+01
# AFR_Non-Exon vs. AFR_4/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.391e-02 U_stat=2.432e+03
# AFR_4/8 vs. AFR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.539e-02 U_stat=7.500e+01
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Non-Exon vs. EAS_1/1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.492e-02 U_stat=1.358e+05
# EUR_Non-Exon vs. EUR_2/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.788e-02 U_stat=5.750e+04
# AMR_Non-Exon vs. AMR_3/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.135e-02 U_stat=5.895e+04
# EUR_Non-Exon vs. EUR_3/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.608e-02 U_stat=5.920e+04
# EAS_2/8 vs. EAS_5/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.352e-03 U_stat=5.160e+02
# /tmp/ipykernel_2457886/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# ## between populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Exon"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [ASSIGN] filler text for any variants which do not have an exon annotation
    TMP.fillna("Non-Exon", inplace=True)

    # [ASSIGN] a numeric sorting key, constructed using the numerator in the fraction-based exon labeling system
    TMP["Exon Sorting Key"] = TMP["Exon"].str.split("/", expand=True)[0]
    
    # [ASSIGN] the correct numerical sorting key for non-exon mutations which did not use the fraction-based exon labeling system
    TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)

    # [ASSIGN] cast the column to a numeric type, to ensure no data-type confusion when plotting
    TMP["Exon Sorting Key"] = to_numeric(TMP["Exon Sorting Key"])

    # [SORT] the TMP DataFrame by the newly created sorting key
    TMP.sort_values(by="Exon Sorting Key", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["exon_between"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        hue_order=sorted(TMP["Exon"].unique().tolist()),
        boxprops={'edgecolor': 'none'},
        order=POPULATIONS_TO_COMPARE
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["exon_between"].get_xticks():
        PLOT[gene]["exon_between"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")

    # [ASSIGN] a list of exons to be analyzed
    exons_found = TMP["Exon"].unique().tolist()

    # [PLOT] set limits on the y-axis
    PLOT[gene]["exon_between"].set(ylim=(0, 1))
    
    # [ASSIGN] a variable to house our tallied up filter expressions
    combinations_between_populations = list()
    
    # [FOR] each exon found...
    for consequence in TMP["Exon"].unique().tolist():
        _tmp = list()
        for population_1, population_2 in combinations(POPULATIONS_TO_COMPARE, 2):
            _tmp.extend([((population_1, consequence), (population_2, consequence))])
        combinations_between_populations.extend(_tmp)
    
    # [STATS] order the combinations so that the annotations wont create visual noise
    combinations_between_populations.sort(key=lambda combination: combination[0])
    
    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["exon_between"],
        combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        order=POPULATIONS_TO_COMPARE,
        hue_order=sorted(exons_found),
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )
    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()
    
    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["exon_between"].axhline(1, _x_min, _x_max, c="gray", ls=":")
    
    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["exon_between"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )
    
    # [PLOT] a title for our plot
    PLOT[gene]["exon_between"].figure.suptitle(
        f"Distribution of allele frequencies by exon (between populations) | {gene}"
    )
    
    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["exon_between"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.329e-03 U_stat=8.712e+03
# AFR_Non-Exon vs. AMR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.131e-02 U_stat=8.636e+03
# EAS_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.160e-02 U_stat=4.796e+03
# OCE_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.298e-03 U_stat=5.056e+03
# SAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.302e-02 U_stat=4.943e+03
# EUR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.289e-10 U_stat=9.930e+03
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.403e-08 U_stat=9.837e+03
# AFR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.476e-03 U_stat=8.928e+03
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.234e-09 U_stat=3.600e+03
# AFR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.526e-10 U_stat=1.025e+04
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.378e-09 U_stat=9.695e+03
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.713e-06 U_stat=9.536e+03
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.277e-15 U_stat=1.084e+04
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.102e-03 U_stat=4.547e+03
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.414e-18 U_stat=1.118e+04
# AMR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.959e-03 U_stat=8.917e+03
# AFR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.280e-09 U_stat=1.004e+04
# AFR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.516e-03 U_stat=8.891e+03
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Non-Exon vs. AMR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.263e-08 U_stat=1.876e+05
# AFR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.436e-07 U_stat=1.867e+05
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.307e-09 U_stat=1.902e+05
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.537e-04 U_stat=1.784e+05
# AFR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.409e-04 U_stat=1.785e+05
# AFR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.091e-04 U_stat=1.794e+05
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.648e-03 U_stat=3.054e+04
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.781e-05 U_stat=4.792e+04
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.751e-03 U_stat=4.554e+04
# EAS_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.759e-02 U_stat=3.100e+04
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.491e-02 U_stat=4.468e+04
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.767e-05 U_stat=2.843e+04
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.734e-02 U_stat=4.470e+04
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.629e-02 U_stat=1.120e+02
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.118e-03 U_stat=4.910e+02
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.940e-05 U_stat=5.280e+02
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Non-Exon vs. AMR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.224e-08 U_stat=1.269e+04
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.482e-05 U_stat=1.178e+04
# SAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.209e-03 U_stat=6.205e+03
# AFR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.297e-04 U_stat=1.181e+04
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.982e-08 U_stat=1.268e+04
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.776e-02 U_stat=6.474e+03
# AFR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.450e-17 U_stat=1.431e+04
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.387e-02 U_stat=1.088e+04
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.318e-06 U_stat=1.213e+04
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.459e-06 U_stat=1.215e+04
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.047e-05 U_stat=5.645e+03
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.895e-08 U_stat=1.249e+04
# AMR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.610e-02 U_stat=1.116e+04
# AFR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.147e-08 U_stat=1.267e+04
# AFR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.334e-04 U_stat=1.169e+04
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.943e-02 U_stat=1.665e+04
# EUR_8/8 vs. OCE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.292e-03 U_stat=9.900e+01
# CSA_8/8 vs. EUR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.599e-02 U_stat=5.190e+02
# CSA_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.541e-08 U_stat=1.871e+04
# EUR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.722e-02 U_stat=9.991e+03
# AMR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.654e-04 U_stat=1.744e+04
# EUR_8/8 vs. UAE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.368e-02 U_stat=1.110e+02
# EUR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.650e-07 U_stat=8.240e+03
# AFR_8/8 vs. EUR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.149e-02 U_stat=5.230e+02
# AMR_8/8 vs. OCE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.872e-03 U_stat=8.400e+01
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.043e-04 U_stat=1.733e+04
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.241e-02 U_stat=2.232e+06
# EAS_2/8 vs. EUR_2/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.276e-02 U_stat=1.289e+03
# OCE_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.296e-02 U_stat=1.936e+06
# EAS_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.548e-04 U_stat=2.271e+06
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.275e-03 U_stat=2.256e+06
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.642e-04 U_stat=1.897e+06
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.175e-06 U_stat=2.299e+06
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.463e-10 U_stat=2.353e+06
# /tmp/ipykernel_2457886/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# # Export

# %%
Path(join(path, "Graphs", "02")).mkdir(exist_ok=True, parents = True)

# %%
for gene in LOCATIONS_COVERED:
    for graph in PLOT[gene].keys(): 
        PLOT[gene][graph].figure.savefig(join(path, "Graphs", "02", f"{gene}_{graph}.jpeg"))
