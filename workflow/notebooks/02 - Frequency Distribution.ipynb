# %% [markdown]
# %%latex
# \tableofcontents

# %% [markdown]
# # Introduction

# %% [markdown]
# Understanding the distribution of variants across population groups, and within population groups is needed to better understand population structure and any forces that may be shaping that structure. This notebook will describe patterns in variant frequency distribution across population groups. Statistical methods will be used to examine differences in frequency distribution between multiple subsets of mutations found, to identify variants of note.
#
# The data used in this notebook  is a valuable tool to identify patterns that are associated with biological function. Using these types of annotations, we describe clinically relevant variants and investigate their impact in greater detail.

# %% [markdown]
# > This notebook will import and make use of data that has already been filtered to identify variants of clinical interest. The criteria used are described in the first notebook of this series, which also describes the code used to perform the data.

# %% [markdown]
# ## Objectives
#
# This notebook will focus on the following objectives:

# %% [markdown]
# - To verify the distribution models that apply to the observed variant frequencies
# - To identify significant differences of variant frequency grouped by consequence type:
#     - between populations
#     - within populations
# - To identify significant differences of variant frequency grouped by exon:
#     - between populations
#     - within populations

# %% [markdown]
# ## Notebook Configuration

# %% [markdown]
# ### Dependencies
#
# This notebook will make use of the following python packages to perform the described analysis:

# %%
from pandas import read_csv, melt, to_numeric
from os.path import join
from statannotations.Annotator import Annotator
from itertools import combinations
from matplotlib.pyplot import (
    xlim,
    figure,
    subplots,
    subplots_adjust,
)
from seaborn import boxplot, move_legend, color_palette, set_theme
from scipy.stats import norm, normaltest
from statsmodels.graphics.gofplots import qqplot
from os.path import join
from pathlib import Path

# %% [markdown]
# ### Data Imports

# %% [markdown]
# Before we start graphing, lets first set up some standard information that will be needed:

# %%
# [ASSIGN] the sample metadata used to conduct the analysis to a reference variable
SAMPLES = read_csv(join("input", "samples.csv"))

# [ASSIGN] the genomic location metadata used to conduct the analysis to a reference variable
LOCATIONS = read_csv(join("input", "locations.csv"))

# [ASSIGN] the dataset metadata used to conduct the analysis to a reference variable
DATASETS = read_csv(join("input", "datasets.csv"))

# [ASSIGN] a sorted list of all the unique population codes found in the annotations used in this analysis.
POPULATIONS_TO_COMPARE = sorted(SAMPLES["super-population"].unique().tolist())

# [ASSIGN] a sorted list of the genomic regions analyzed
LOCATIONS_COVERED = sorted(LOCATIONS["location_name"].unique().tolist())

# %% [markdown]
# Next, lets import the results, which are stored in the form of CSV files grouped by cluster annotations provided during the analysis. This notebook will focus on the analysis of the clusters annotated in the super-population group.

# %%
# [SET] a dictionary to be used to house our data, indexed by gene
DATA = dict()

# [FOR] each gene in our list of gene regions included in this analysis...
for gene in LOCATIONS_COVERED:
    # [ASSIGN] a DataFrame containing our imported gene-specific datasets to our DATA object
    DATA[gene] = read_csv(
        join(
            "/",
            "mnt",
            "ICMM_HDD_12TB",
            "Results_25SEP2024",
            "cleaned",
            f"super-population_{gene}.csv.zst",
        )
    )
    DATA[gene].rename(columns={
        "Consequence_type": "Consequence"
    }, inplace=True)

# %%
# [FOR] each gene in our list of gene regions analyzed
for gene in LOCATIONS_COVERED:
    # [ASSIGN] the replaced column of data
    DATA[gene]["Consequence"] = DATA[gene]["Consequence"].replace({
    "regulatory_region_variant": "Regulatory Region",
    "upstream_gene_variant": "Upstream",
    "splice_polypyrimidine_tract_variant": "Splice Polypyrimidine Tract",
    "synonymous_variant": "Synonymous",
    "3_prime_UTR_variant": "3' UTR",
    "5_prime_UTR_variant": "5' UTR",
    "intergenic_variant": "Intergenic",
    "splice_region_variant": "Splice Region",
    "intron_variant": "Intron",
    "stop_gained": "Stop-Gain",
    "splice_donor_region_variant": "Splice Doner Region",
    "missense_variant": "Missense",
    "splice_acceptor_variant": "Splice Acceptor",
    "non_coding_transcript_exon_variant": "Non-Coding Transcript Exon",
    "downstream_gene_variant": "Downstream Gene",
    "TF_binding_site_variant": "TF Binding Site",
})

# %% [markdown]
# ### Plot storage and configuration

# %% [markdown]
# To store our generated plots, we can use a python dictionary to store these in a hierarchical index, using the name of each gene region to order collections of related plots together. We can also make use of nested dictionaries to store multiple plot types for each gene.

# %%
# [STORE] of all plots we will be making.
PLOT = dict()

# [FOR] each gene, create a storage space for any plots generated (This should use a hierarchical storage structure of PLOT[gene][graph])
for gene in LOCATIONS_COVERED:

    # [ASSIGN] an empty dictionary to store all plots made for this gene
    PLOT[gene] = dict()

# [ASSIGN] a generic record to house plots that apply across genes
PLOT[None] = dict()

# %% [markdown]
# Lets also set a few theme options that will apply to all of our plots:

# %%
# [CREDIT] for ratio sizes goes to a Bio-render article I found which talks about plot sizes
# https://www.biorender.com/blog/why-layout-and-scale-matters-for-graphs
set_theme(rc={"figure.figsize": (10, 7)}, style="ticks", palette="hls")

# %% [markdown]
# # Allele Frequency Distribution

# %% [markdown]
# First, lets look at the distribution of observed allele frequencies. This can be done using the Seaborn plot, [`boxplot`](https://seaborn.pydata.org/generated/seaborn.boxplot.html). By investigating these distribution observed, we can identify statistically significant differences within and between our population groups. We can use the [statannotations](https://pypi.org/project/statannotations/) package to run and apply statistical annotations to our boxplots.

# %% [markdown]
# ## Q-Q plot with test for normality

# %% [markdown]
# In order to better understand the patterns in our data, lets start by visualizing the distribution of variant frequency across different grouping types. By visualizing our data in sets or groups, we can use statistics such as or derived from the Chi-Squared statistic to identify sets with significantly different distributions.
#
# For this task, we can use the python [`statannotations`](https://pypi.org/project/statannotations/) package which provides an interface to access statistical functions offered by the wll-known [`scipy`](https://scipy.org/) statistical package, and apply these to plots generated using [`seaborn`](https://seaborn.pydata.org/), another well-known python graphing library. This facility offers the use of the following scipy statistical functions:
#
# - [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) | Mann-Whitney test
# - [`ttest_ind`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind) & [`ttest_rel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html#ttest-rel) | t-test (independent and paired)
# - [`ttest_ind`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html#ttest-ind) | Welch's t-test
# - [`levene`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html#levene) | Levene test
# - [`wilcoxon`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html#wilcoxon) | Wilcoxon test
# - [`kruskal`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kruskal.html#scipy.stats.kruskal) | Kruskal-Wallis test
# - [`brunnermunzel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.brunnermunzel.html#scipy.stats.brunnermunzel) | Brunner-Munzel test

# %% [markdown]
# The [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) method is ideal for our purposes since it is designed for unrelated samples. `Scipy.stats` does however note that in situations where the data being analyzed follows a normal-distribution, that a T-test would be more appropriate. Given this, we will first have to perform a test of distribution to determine if our data follows a normal distribution. For this, we can make use of the [`qqplot`](https://www.statsmodels.org/stable/generated/statsmodels.graphics.gofplots.qqplot.html) function from [`statsmodels`](https://www.statsmodels.org/stable/index.html).
#
# A Q-Q Plot is used to understand how well our data fits to known models of distribution, such as the famous normal distribution. This is done by plotting the theoretical quartiles on the x-axis and our observed quartiles on the y-axis. In this case, we will generate a regression-line to indicate the goodness-of-fit visually.

# %%
# [ASSIGN] the number of rows and columns to be made in this subplot
_nrows = len(LOCATIONS_COVERED)
_ncols = len(POPULATIONS_TO_COMPARE)

# [ASSIGN] the subplot figure and axes objects to variables for plotting and formatting
PLOT[None]["Q-Q Plot (Frequency)"], axes = subplots(
    _nrows,
    _ncols,
    sharex=True,
    sharey=True,
)

# [ASSIGN] a new plot title
PLOT[None]["Q-Q Plot (Frequency)"].suptitle("Q-Q Distribution Test | Normal Distribution")

# [ASSIGN] a new plot x-label
PLOT[None]["Q-Q Plot (Frequency)"].supxlabel("Theoretical Quantiles")

# [ASSIGN] a new plot y-label
PLOT[None]["Q-Q Plot (Frequency)"].supylabel("Sample Quantiles")

# [MUTATE] the subplot to add a bit more spacing between the plot and its X and Y axis labels
subplots_adjust(left=0.135, bottom=0.15)

# [FOR] each gene in our list of genes
for geneIndex, gene in enumerate(LOCATIONS_COVERED):
    # [FOR] each population in our list of population groups
    for populationIndex, population in enumerate(POPULATIONS_TO_COMPARE):
        # [ASSIGN] the results of the test for normality for later use
        isNormal = normaltest(DATA[gene][population])

        # [IF] the p-value from our normality-test is less-than or equal to 0.05, we can safely reject the null hypothesis:
        if isNormal.pvalue <= 0.05:
            # [MUTATE] set the sub-plot background color to indicate significance
            axes[geneIndex, populationIndex].set_facecolor("#ff000066")
        else:
            axes[geneIndex, populationIndex].set_facecolor("lightgray")

        # [PLOT] a Q-Q plot for a spesific gene-population pair to the apropriate sub-plot axes
        qqplot(
            DATA[gene][population],
            dist=norm,
            fit=True,
            line="r",
            ax=axes[geneIndex, populationIndex],
        )

        # [MUTATE] activate the grid on the plots for ease-of-reference
        axes[geneIndex, populationIndex].grid(True)
        
        # [MUTATE] remove the x-label from the individual sub-plot or there will be too much clutter
        axes[geneIndex, populationIndex].set_xlabel("")
        
        # [MUTATE] remove the y-label from the individual sub-plot or there will be too much clutter
        axes[geneIndex, populationIndex].set_ylabel("")
        
        # [MUTATE] rotate the label ticks and make them slightly smaller
        axes[geneIndex, populationIndex].tick_params(labelrotation=90, labelsize=7)

# [FOR] each gene in our list of genes
for geneIndex, gene in enumerate(LOCATIONS_COVERED):
    # [ASSIGN] a single set of y-labels (gene) to only the first column of the grid of plots
    axes[geneIndex, 0].set_ylabel(f"{gene}", rotation=65, size=8)

# [FOR] each population in our list of population groups
for populationIndex, population in enumerate(POPULATIONS_TO_COMPARE):
    # [ASSIGN] a single set of x-labels (population) to only the last row of the grid of plots
    axes[_nrows - 1, populationIndex].set_xlabel(f"{population}", size=8)
# Out:
# /home/students/miniconda3/envs/GRAEME_statannotations/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:418: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=9 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %% [markdown]
# As we can see from the above Q-Q plot, most of our gene-regions are noted with a significant p value. Although the data does show some degree of correlation, our normality test shows that there is a low probability of observing the frequencies found in the CYP2B6, CYP2C9, CYP2C19, CYP2D6, CYP4F2, HLA-A and HLA-B gene regions in a normally distributed dataset. Low-enough for us to confidently reject our null hypothesis that these frequency observations could have been sampled from a normally distributed population.
#
# Based on the above findings, it will not be advisable to use a T-test, as this type of test relies on the assumption of normality. For this reason, we will opt for using the Mann-Whitney U-test, provided via the [`mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html#scipy.stats.mannwhitneyu) function.

# %% [markdown]
# # Frequency distribution by consequence type

# %% [markdown]
# Now lets take a closer look at our frequency distribution from before, but this time, lets separate the data into groups by consequence type.

# %% [markdown]
# ## within populations

# %%
# [FOR] gene in genes to be analyzed
for gene in LOCATIONS_COVERED:
    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Consequence"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [ASSIGN] a sorted list of exons to be analyzed
    consequences_found = sorted(TMP["Consequence"].unique().tolist())
    
    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["consequence_within"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        boxprops={'edgecolor': 'none'},
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["consequence_within"].get_xticks():
        PLOT[gene]["consequence_within"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")


    # [PLOT] set limits on the y-axis
    PLOT[gene]["consequence_within"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    consequence_combinations_within_populations = list()

    # [FOR] each combination of any two consequence types possible...
    for consequence_1, consequence_2 in combinations(consequences_found, 2):
        # [ASSIGN] a temporary variable to house all combinations for the above-two consequences
        _tmp = list()

        # [FOR] each population in our list of populations to be compared
        for population in POPULATIONS_TO_COMPARE:
            # [ASSIGN] a set of comparison expressions to compare these two consequences within our populations
            _tmp.append(
                (( population, consequence_1), (population, consequence_2)),
            )
        # [ASSIGN] the filter expressions generated for the above consequence-comparison across all populations into our tally variable
        consequence_combinations_within_populations.extend(_tmp)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["consequence_within"],
        consequence_combinations_within_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )

    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["consequence_within"].axhline(1.0, _x_min, _x_max, color="gray", linestyle="--")

    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["consequence_within"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["consequence_within"].figure.suptitle(
        f"Distribution of allele frequencies by consequence type (within populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["consequence_within"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# SAS_Upstream vs. SAS_Synonymous: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.864e-02 U_stat=8.830e+02
# SAS_Synonymous vs. SAS_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.418e-02 U_stat=8.300e+01
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Intergenic vs. AFR_Regulatory Region: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.864e-03 U_stat=4.351e+04
# EUR_Missense vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.732e-03 U_stat=7.602e+03
# CSA_Downstream Gene vs. CSA_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.262e-05 U_stat=1.428e+05
# EAS_Downstream Gene vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.689e-10 U_stat=1.321e+05
# EUR_Downstream Gene vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.020e-15 U_stat=1.242e+05
# SAS_Downstream Gene vs. SAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.716e-04 U_stat=1.463e+05
# UAE_Downstream Gene vs. UAE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.866e-06 U_stat=1.419e+05
# EUR_Upstream vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.191e-03 U_stat=1.101e+05
# AFR_Downstream Gene vs. AFR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.978e-18 U_stat=1.193e+05
# EAS_Non-Coding Transcript Exon vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.162e-06 U_stat=3.246e+04
# EUR_Non-Coding Transcript Exon vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.323e-04 U_stat=3.397e+04
# AFR_Non-Coding Transcript Exon vs. AFR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.076e-03 U_stat=3.588e+04
# EAS_Upstream vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.604e-04 U_stat=1.237e+05
# EUR_Upstream vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.916e-03 U_stat=1.250e+05
# OCE_Upstream vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.221e-10 U_stat=1.882e+05
# SAS_Upstream vs. SAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.332e-09 U_stat=1.131e+05
# UAE_Upstream vs. UAE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.002e-08 U_stat=1.140e+05
# CSA_Upstream vs. CSA_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.872e-12 U_stat=1.087e+05
# AFR_Upstream vs. AFR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.174e-12 U_stat=1.079e+05
# EUR_Intron vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.721e-07 U_stat=3.622e+04
# AMR_Missense vs. AMR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.834e-05 U_stat=1.100e+04
# SAS_Missense vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.391e-04 U_stat=1.157e+04
# EUR_Missense vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.455e-10 U_stat=8.862e+03
# SAS_Missense vs. SAS_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.509e-04 U_stat=3.204e+03
# AMR_Missense vs. AMR_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.337e-02 U_stat=3.606e+03
# EUR_Missense vs. EUR_Non-Coding Transcript Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.136e-05 U_stat=3.077e+03
# SAS_Missense vs. SAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.944e-06 U_stat=1.229e+04
# EUR_Synonymous vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.237e-02 U_stat=6.014e+03
# AMR_Missense vs. AMR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.605e-04 U_stat=1.318e+04
# EUR_Missense vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.028e-06 U_stat=1.242e+04
# EAS_Intron vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.643e-10 U_stat=6.794e+04
# EUR_Intron vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.951e-17 U_stat=6.000e+04
# CSA_Intron vs. CSA_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.458e-05 U_stat=7.490e+04
# AFR_Intron vs. AFR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.559e-19 U_stat=5.749e+04
# OCE_Intron vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.508e-06 U_stat=1.197e+05
# SAS_Intron vs. SAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.460e-08 U_stat=7.002e+04
# UAE_Intron vs. UAE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.419e-03 U_stat=7.798e+04
# SAS_Missense vs. SAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.052e-10 U_stat=1.691e+04
# UAE_Missense vs. UAE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.534e-02 U_stat=2.402e+04
# AMR_Missense vs. AMR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.425e-04 U_stat=2.158e+04
# EAS_Missense vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.733e-04 U_stat=2.197e+04
# EUR_Missense vs. EUR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.392e-12 U_stat=1.602e+04
# EUR_Intron vs. EUR_Regulatory Region: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.279e-02 U_stat=8.198e+03
# AFR_Missense vs. AFR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.857e-02 U_stat=2.406e+04
# SAS_Missense vs. SAS_Regulatory Region: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.915e-04 U_stat=2.259e+03
# EUR_Missense vs. EUR_Regulatory Region: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.301e-05 U_stat=2.106e+03
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# ## between populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Consequence"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population"
    )
     
    # [REPLACE] null values with "Non-Exon" for graphing purposes.
    TMP.fillna("Non-Exon", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [ASSIGN] a list of consequences to be analyzed
    consequences_found = sorted(TMP["Consequence"].unique().tolist())

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["consequence_between"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        boxprops={'edgecolor': 'none'}
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["consequence_between"].get_xticks():
        PLOT[gene]["consequence_between"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")
        
    # [PLOT] set limits on the y-axis
    PLOT[gene]["consequence_between"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    consequence_combinations_between_populations = list()
    
    # [FOR] each consequence type found...
    for consequence in TMP["Consequence"].unique().tolist():
        _tmp = list()
        # [FOR] each combination of any two consequence types possible...
        for population_1, population_2 in combinations(POPULATIONS_TO_COMPARE, 2):
            # [ASSIGN] a set of comparison expressions to compare these two consequences between our populations
            _tmp.extend([((population_1, consequence), (population_2, consequence))])
        
        # [ASSIGN] the filter expressions generated for the above consequence-comparison across all populations into our tally variable
        consequence_combinations_between_populations.extend(_tmp)

    # [SORT] these combinations and order them by exon, which will be our conditional-split/nested x-axis in this graph.
    print(consequence_combinations_between_populations)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["consequence_between"],
        consequence_combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        order=POPULATIONS_TO_COMPARE,
        hue="Consequence",
        hue_order=consequences_found,
        show_test_name=True
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )

    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["consequence_between"].axhline(1, _x_min, _x_max, c="gray", ls=":")

    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["consequence_between"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["consequence_between"].figure.suptitle(
        f"Distribution of allele frequencies by consequence type (between populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["consequence_between"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# [(('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EAS' ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.158e-07 U_stat=3.142e+03
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.315e-03 U_stat=2.848e+03
# OCE_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.417e-07 U_stat=8.025e+02
# AFR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.826e-04 U_stat=2.957e+03
# AMR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.947e-02 U_stat=2.732e+03
# CSA_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.671e-07 U_stat=3.160e+03
# AFR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.012e-04 U_stat=2.910e+03
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.782e-09 U_stat=3.316e+03
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.892e-02 U_stat=1.264e+03
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.519e-11 U_stat=3.418e+03
# AMR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.439e-02 U_stat=2.738e+03
# AFR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.659e-04 U_stat=2.946e+03
# [(('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Stop-Gain'), ('AMR', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('CSA', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('AFR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('CSA', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('AMR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('EAS', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('CSA', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('EUR', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('EAS', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('OCE', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('EUR', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('OCE', 'Stop-Gain'), ('SAS', 'Stop-Gain')), (('OCE', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('SAS', 'Stop-Gain'), ('UAE', 'Stop-Gain')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), ( ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.541e-04 U_stat=5.293e+04
# AMR_Intron vs. CSA_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.516e-06 U_stat=4.975e+04
# SAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.861e-03 U_stat=7.771e+04
# OCE_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.325e-04 U_stat=7.965e+04
# EUR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.444e-02 U_stat=5.572e+04
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.550e-04 U_stat=5.281e+04
# AMR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.264e-05 U_stat=5.164e+04
# CSA_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.151e-03 U_stat=7.741e+04
# [(('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('EUR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('OCE', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('OCE', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('SAS', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'M ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Intron vs. CSA_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.023e-02 U_stat=1.643e+04
# EAS_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.996e-05 U_stat=1.518e+04
# CSA_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.070e-06 U_stat=2.786e+04
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.216e-03 U_stat=2.633e+04
# EAS_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.424e-05 U_stat=1.505e+04
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.139e-07 U_stat=1.400e+04
# AMR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.717e-02 U_stat=1.672e+04
# [(('AFR', "3' UTR"), ('AMR', "3' UTR")), (('AFR', "3' UTR"), ('CSA', "3' UTR")), (('AFR', "3' UTR"), ('EAS', "3' UTR")), (('AFR', "3' UTR"), ('EUR', "3' UTR")), (('AFR', "3' UTR"), ('OCE', "3' UTR")), (('AFR', "3' UTR"), ('SAS', "3' UTR")), (('AFR', "3' UTR"), ('UAE', "3' UTR")), (('AMR', "3' UTR"), ('CSA', "3' UTR")), (('AMR', "3' UTR"), ('EAS', "3' UTR")), (('AMR', "3' UTR"), ('EUR', "3' UTR")), (('AMR', "3' UTR"), ('OCE', "3' UTR")), (('AMR', "3' UTR"), ('SAS', "3' UTR")), (('AMR', "3' UTR"), ('UAE', "3' UTR")), (('CSA', "3' UTR"), ('EAS', "3' UTR")), (('CSA', "3' UTR"), ('EUR', "3' UTR")), (('CSA', "3' UTR"), ('OCE', "3' UTR")), (('CSA', "3' UTR"), ('SAS', "3' UTR")), (('CSA', "3' UTR"), ('UAE', "3' UTR")), (('EAS', "3' UTR"), ('EUR', "3' UTR")), (('EAS', "3' UTR"), ('OCE', "3' UTR")), (('EAS', "3' UTR"), ('SAS', "3' UTR")), (('EAS', "3' UTR"), ('UAE', "3' UTR")), (('EUR', "3' UTR"), ('OCE', "3' UTR")), (('EUR', "3' UTR"), ('SAS', "3' UTR")), (('EUR', "3' UTR"), ('UAE', "3' UTR")), (('OCE', "3' UTR"), ('SAS', "3' UTR")), (('OCE', "3' UTR"), ('UAE', "3' UTR")), (('SAS', "3' UTR"), ('UAE', "3' UTR")), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('AMR', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('SAS', 'Splice Polypyrimidine Tract')), (('CSA', 'Splice Polypyrimidine Tract'), ('UAE', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice Polypyrimidine Tract')), (('EAS', 'Splice Polypyrimidine Tract'), ('OCE', 'Splice Polypyrimidine Tract')), (('EAS' ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Missense vs. OCE_Missense: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.504e-02 U_stat=1.550e+02
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.548e-03 U_stat=2.430e+02
# [(('AFR', "3' UTR"), ('AMR', "3' UTR")), (('AFR', "3' UTR"), ('CSA', "3' UTR")), (('AFR', "3' UTR"), ('EAS', "3' UTR")), (('AFR', "3' UTR"), ('EUR', "3' UTR")), (('AFR', "3' UTR"), ('OCE', "3' UTR")), (('AFR', "3' UTR"), ('SAS', "3' UTR")), (('AFR', "3' UTR"), ('UAE', "3' UTR")), (('AMR', "3' UTR"), ('CSA', "3' UTR")), (('AMR', "3' UTR"), ('EAS', "3' UTR")), (('AMR', "3' UTR"), ('EUR', "3' UTR")), (('AMR', "3' UTR"), ('OCE', "3' UTR")), (('AMR', "3' UTR"), ('SAS', "3' UTR")), (('AMR', "3' UTR"), ('UAE', "3' UTR")), (('CSA', "3' UTR"), ('EAS', "3' UTR")), (('CSA', "3' UTR"), ('EUR', "3' UTR")), (('CSA', "3' UTR"), ('OCE', "3' UTR")), (('CSA', "3' UTR"), ('SAS', "3' UTR")), (('CSA', "3' UTR"), ('UAE', "3' UTR")), (('EAS', "3' UTR"), ('EUR', "3' UTR")), (('EAS', "3' UTR"), ('OCE', "3' UTR")), (('EAS', "3' UTR"), ('SAS', "3' UTR")), (('EAS', "3' UTR"), ('UAE', "3' UTR")), (('EUR', "3' UTR"), ('OCE', "3' UTR")), (('EUR', "3' UTR"), ('SAS', "3' UTR")), (('EUR', "3' UTR"), ('UAE', "3' UTR")), (('OCE', "3' UTR"), ('SAS', "3' UTR")), (('OCE', "3' UTR"), ('UAE', "3' UTR")), (('SAS', "3' UTR"), ('UAE', "3' UTR")), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Intron vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.451e-07 U_stat=7.497e+03
# CSA_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.623e-06 U_stat=7.174e+03
# SAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.259e-02 U_stat=3.470e+03
# AFR_Intron vs. CSA_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.517e-03 U_stat=6.700e+03
# AMR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.307e-07 U_stat=7.394e+03
# AFR_Intron vs. EAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.816e-15 U_stat=8.408e+03
# AFR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.793e-03 U_stat=6.693e+03
# AMR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.115e-03 U_stat=6.601e+03
# EAS_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.917e-04 U_stat=3.120e+03
# AFR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.994e-03 U_stat=6.677e+03
# AFR_Intron vs. SAS_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.888e-04 U_stat=6.972e+03
# AFR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.538e-03 U_stat=6.680e+03
# [(('AFR', 'Upstream'), ('AMR', 'Upstream')), (('AFR', 'Upstream'), ('CSA', 'Upstream')), (('AFR', 'Upstream'), ('EAS', 'Upstream')), (('AFR', 'Upstream'), ('EUR', 'Upstream')), (('AFR', 'Upstream'), ('OCE', 'Upstream')), (('AFR', 'Upstream'), ('SAS', 'Upstream')), (('AFR', 'Upstream'), ('UAE', 'Upstream')), (('AMR', 'Upstream'), ('CSA', 'Upstream')), (('AMR', 'Upstream'), ('EAS', 'Upstream')), (('AMR', 'Upstream'), ('EUR', 'Upstream')), (('AMR', 'Upstream'), ('OCE', 'Upstream')), (('AMR', 'Upstream'), ('SAS', 'Upstream')), (('AMR', 'Upstream'), ('UAE', 'Upstream')), (('CSA', 'Upstream'), ('EAS', 'Upstream')), (('CSA', 'Upstream'), ('EUR', 'Upstream')), (('CSA', 'Upstream'), ('OCE', 'Upstream')), (('CSA', 'Upstream'), ('SAS', 'Upstream')), (('CSA', 'Upstream'), ('UAE', 'Upstream')), (('EAS', 'Upstream'), ('EUR', 'Upstream')), (('EAS', 'Upstream'), ('OCE', 'Upstream')), (('EAS', 'Upstream'), ('SAS', 'Upstream')), (('EAS', 'Upstream'), ('UAE', 'Upstream')), (('EUR', 'Upstream'), ('OCE', 'Upstream')), (('EUR', 'Upstream'), ('SAS', 'Upstream')), (('EUR', 'Upstream'), ('UAE', 'Upstream')), (('OCE', 'Upstream'), ('SAS', 'Upstream')), (('OCE', 'Upstream'), ('UAE', 'Upstream')), (('SAS', 'Upstream'), ('UAE', 'Upstream')), (('AFR', "5' UTR"), ('AMR', "5' UTR")), (('AFR', "5' UTR"), ('CSA', "5' UTR")), (('AFR', "5' UTR"), ('EAS', "5' UTR")), (('AFR', "5' UTR"), ('EUR', "5' UTR")), (('AFR', "5' UTR"), ('OCE', "5' UTR")), (('AFR', "5' UTR"), ('SAS', "5' UTR")), (('AFR', "5' UTR"), ('UAE', "5' UTR")), (('AMR', "5' UTR"), ('CSA', "5' UTR")), (('AMR', "5' UTR"), ('EAS', "5' UTR")), (('AMR', "5' UTR"), ('EUR', "5' UTR")), (('AMR', "5' UTR"), ('OCE', "5' UTR")), (('AMR', "5' UTR"), ('SAS', "5' UTR")), (('AMR', "5' UTR"), ('UAE', "5' UTR")), (('CSA', "5' UTR"), ('EAS', "5' UTR")), (('CSA', "5' UTR"), ('EUR', "5' UTR")), (('CSA', "5' UTR"), ('OCE', "5' UTR")), (('CSA', "5' UTR"), ('SAS', "5' UTR")), (('CSA', "5' UTR"), ('UAE', "5' UTR")), (('EAS', "5' UTR"), ('EUR', "5' UTR")), (('EAS', "5' UTR"), ('OCE', "5' UTR")), (('EAS', "5' UTR"), ('SAS', "5' UTR")), (('EAS', "5' UTR"), ('UAE', "5' UTR")), (('EUR', "5' UTR"), ('OCE', "5' UTR")), (('EUR', "5' UTR"), ('SAS', "5' UTR")), (('EUR', "5' UTR"), ('UAE', "5' UTR")), (('OCE', "5' UTR"), ('SAS', "5' UTR")), (('OCE', "5' UTR"), ('UAE', "5' UTR")), (('SAS', "5' UTR"), ('UAE', "5' UTR")), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_3' UTR vs. OCE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.063e-02 U_stat=9.000e+01
# EUR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.512e-04 U_stat=4.900e+02
# CSA_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.087e-04 U_stat=1.749e+03
# CSA_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.893e-07 U_stat=5.936e+03
# EUR_3' UTR vs. SAS_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.427e-03 U_stat=7.600e+01
# CSA_3' UTR vs. EUR_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.667e-03 U_stat=4.710e+02
# EUR_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.729e-02 U_stat=5.745e+02
# AMR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.216e-04 U_stat=5.516e+03
# EUR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.423e-07 U_stat=1.770e+03
# EUR_3' UTR vs. UAE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.009e-03 U_stat=6.400e+01
# AFR_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.215e-04 U_stat=1.748e+03
# AFR_3' UTR vs. EUR_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.097e-03 U_stat=4.750e+02
# AMR_3' UTR vs. OCE_3' UTR: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.630e-03 U_stat=6.500e+01
# AFR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.895e-03 U_stat=1.696e+03
# [(('AFR', 'Missense'), ('AMR', 'Missense')), (('AFR', 'Missense'), ('CSA', 'Missense')), (('AFR', 'Missense'), ('EAS', 'Missense')), (('AFR', 'Missense'), ('EUR', 'Missense')), (('AFR', 'Missense'), ('OCE', 'Missense')), (('AFR', 'Missense'), ('SAS', 'Missense')), (('AFR', 'Missense'), ('UAE', 'Missense')), (('AMR', 'Missense'), ('CSA', 'Missense')), (('AMR', 'Missense'), ('EAS', 'Missense')), (('AMR', 'Missense'), ('EUR', 'Missense')), (('AMR', 'Missense'), ('OCE', 'Missense')), (('AMR', 'Missense'), ('SAS', 'Missense')), (('AMR', 'Missense'), ('UAE', 'Missense')), (('CSA', 'Missense'), ('EAS', 'Missense')), (('CSA', 'Missense'), ('EUR', 'Missense')), (('CSA', 'Missense'), ('OCE', 'Missense')), (('CSA', 'Missense'), ('SAS', 'Missense')), (('CSA', 'Missense'), ('UAE', 'Missense')), (('EAS', 'Missense'), ('EUR', 'Missense')), (('EAS', 'Missense'), ('OCE', 'Missense')), (('EAS', 'Missense'), ('SAS', 'Missense')), (('EAS', 'Missense'), ('UAE', 'Missense')), (('EUR', 'Missense'), ('OCE', 'Missense')), (('EUR', 'Missense'), ('SAS', 'Missense')), (('EUR', 'Missense'), ('UAE', 'Missense')), (('OCE', 'Missense'), ('SAS', 'Missense')), (('OCE', 'Missense'), ('UAE', 'Missense')), (('SAS', 'Missense'), ('UAE', 'Missense')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Splice Polypyrimidine Tract'), ('AMR', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('CSA', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EAS', 'Splice Polypyrimidine Tract')), (('AFR', 'Splice Polypyrimidine Tract'), ('EUR', 'Splice  ...
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_Intron vs. OCE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.661e-02 U_stat=2.644e+04
# AFR_Intron vs. AMR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.769e-02 U_stat=2.613e+04
# AFR_Upstream vs. AMR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.513e-08 U_stat=5.806e+04
# AMR_Upstream vs. CSA_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.751e-06 U_stat=9.847e+04
# EAS_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.452e-03 U_stat=6.509e+04
# EUR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.593e-03 U_stat=6.515e+04
# OCE_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.050e-05 U_stat=9.707e+04
# AFR_Downstream Gene vs. AMR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.895e-08 U_stat=8.261e+04
# AFR_Intergenic vs. AMR_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.101e-04 U_stat=3.268e+05
# EUR_Intergenic vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.346e-22 U_stat=3.713e+05
# OCE_Intergenic vs. SAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.499e-18 U_stat=2.051e+05
# CSA_Missense vs. EUR_Missense: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.178e-03 U_stat=5.299e+03
# AMR_Upstream vs. EAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.652e-03 U_stat=9.364e+04
# CSA_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.454e-04 U_stat=6.357e+04
# EUR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.507e-03 U_stat=9.433e+04
# OCE_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.196e-03 U_stat=9.346e+04
# AFR_Downstream Gene vs. CSA_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.674e-04 U_stat=8.878e+04
# AMR_Downstream Gene vs. EAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.269e-05 U_stat=1.308e+05
# EAS_Intergenic vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.287e-22 U_stat=3.708e+05
# OCE_Intergenic vs. UAE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.384e-22 U_stat=1.975e+05
# EUR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.539e-03 U_stat=2.562e+04
# AMR_Intron vs. EUR_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.567e-02 U_stat=3.996e+04
# CSA_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.148e-02 U_stat=6.599e+04
# EUR_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.499e-04 U_stat=9.563e+04
# AMR_Downstream Gene vs. EUR_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.402e-05 U_stat=1.314e+05
# AFR_Intergenic vs. EAS_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.130e-03 U_stat=3.206e+05
# CSA_Intergenic vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.619e-26 U_stat=3.788e+05
# AFR_Missense vs. EUR_Missense: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.966e-02 U_stat=5.138e+03
# AFR_Upstream vs. EUR_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.555e-07 U_stat=5.921e+04
# AMR_Intergenic vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.258e-21 U_stat=3.695e+05
# AFR_Upstream vs. OCE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.490e-06 U_stat=6.123e+04
# AMR_Upstream vs. SAS_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.902e-06 U_stat=9.789e+04
# AFR_Intergenic vs. OCE_Intergenic: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.669e-23 U_stat=3.722e+05
# AMR_Upstream vs. UAE_Upstream: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.975e-05 U_stat=9.672e+04
# AFR_Downstream Gene vs. SAS_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.008e-04 U_stat=8.903e+04
# AMR_Downstream Gene vs. UAE_Downstream Gene: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.674e-02 U_stat=1.250e+05
# AFR_Intron vs. UAE_Intron: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.149e-03 U_stat=2.578e+04
# [(('AFR', 'Synonymous'), ('AMR', 'Synonymous')), (('AFR', 'Synonymous'), ('CSA', 'Synonymous')), (('AFR', 'Synonymous'), ('EAS', 'Synonymous')), (('AFR', 'Synonymous'), ('EUR', 'Synonymous')), (('AFR', 'Synonymous'), ('OCE', 'Synonymous')), (('AFR', 'Synonymous'), ('SAS', 'Synonymous')), (('AFR', 'Synonymous'), ('UAE', 'Synonymous')), (('AMR', 'Synonymous'), ('CSA', 'Synonymous')), (('AMR', 'Synonymous'), ('EAS', 'Synonymous')), (('AMR', 'Synonymous'), ('EUR', 'Synonymous')), (('AMR', 'Synonymous'), ('OCE', 'Synonymous')), (('AMR', 'Synonymous'), ('SAS', 'Synonymous')), (('AMR', 'Synonymous'), ('UAE', 'Synonymous')), (('CSA', 'Synonymous'), ('EAS', 'Synonymous')), (('CSA', 'Synonymous'), ('EUR', 'Synonymous')), (('CSA', 'Synonymous'), ('OCE', 'Synonymous')), (('CSA', 'Synonymous'), ('SAS', 'Synonymous')), (('CSA', 'Synonymous'), ('UAE', 'Synonymous')), (('EAS', 'Synonymous'), ('EUR', 'Synonymous')), (('EAS', 'Synonymous'), ('OCE', 'Synonymous')), (('EAS', 'Synonymous'), ('SAS', 'Synonymous')), (('EAS', 'Synonymous'), ('UAE', 'Synonymous')), (('EUR', 'Synonymous'), ('OCE', 'Synonymous')), (('EUR', 'Synonymous'), ('SAS', 'Synonymous')), (('EUR', 'Synonymous'), ('UAE', 'Synonymous')), (('OCE', 'Synonymous'), ('SAS', 'Synonymous')), (('OCE', 'Synonymous'), ('UAE', 'Synonymous')), (('SAS', 'Synonymous'), ('UAE', 'Synonymous')), (('AFR', 'Intron'), ('AMR', 'Intron')), (('AFR', 'Intron'), ('CSA', 'Intron')), (('AFR', 'Intron'), ('EAS', 'Intron')), (('AFR', 'Intron'), ('EUR', 'Intron')), (('AFR', 'Intron'), ('OCE', 'Intron')), (('AFR', 'Intron'), ('SAS', 'Intron')), (('AFR', 'Intron'), ('UAE', 'Intron')), (('AMR', 'Intron'), ('CSA', 'Intron')), (('AMR', 'Intron'), ('EAS', 'Intron')), (('AMR', 'Intron'), ('EUR', 'Intron')), (('AMR', 'Intron'), ('OCE', 'Intron')), (('AMR', 'Intron'), ('SAS', 'Intron')), (('AMR', 'Intron'), ('UAE', 'Intron')), (('CSA', 'Intron'), ('EAS', 'Intron')), (('CSA', 'Intron'), ('EUR', 'Intron')), (('CSA', 'Intron'), ('OCE', 'Intron')), (('CSA', 'Intron'), ('SAS', 'Intron')), (('CSA', 'Intron'), ('UAE', 'Intron')), (('EAS', 'Intron'), ('EUR', 'Intron')), (('EAS', 'Intron'), ('OCE', 'Intron')), (('EAS', 'Intron'), ('SAS', 'Intron')), (('EAS', 'Intron'), ('UAE', 'Intron')), (('EUR', 'Intron'), ('OCE', 'Intron')), (('EUR', 'Intron'), ('SAS', 'Intron')), (('EUR', 'Intron'), ('UAE', 'Intron')), (('OCE', 'Intron'), ('SAS', 'Intron')), (('OCE', 'Intron'), ('UAE', 'Intron')), (('SAS', 'Intron'), ('UAE', 'Intron')), (('AFR', 'Upstream'), ('AMR', 'Upstream')), (('AFR', 'Upstream'), ('CSA', 'Upstream')), (('AFR', 'Upstream'), ('EAS', 'Upstream')), (('AFR', 'Upstream'), ('EUR', 'Upstream')), (('AFR', 'Upstream'), ('OCE', 'Upstream')), (('AFR', 'Upstream'), ('SAS', 'Upstream')), (('AFR', 'Upstream'), ('UAE', 'Upstream')), (('AMR', 'Upstream'), ('CSA', 'Upstream')), (('AMR', 'Upstream'), ('EAS', 'Upstream')), (('AMR', 'Upstream'), ('EUR', 'Upstream')), (('AMR', 'Upstream'), ('OCE', 'Upstream')), (('AMR', 'Upstream'), ('SAS', 'Upstream')), (('AMR', 'Upstream'), ('UAE', 'Upstream')), (('CSA', 'Upstream'), ('EAS', 'Upstream')), (('CSA', 'Upstream'), ('EUR', 'Upstream')), (('CSA', 'Upstream'), ('OCE', 'Upstream')), (('CSA', 'Upstream'), ('SAS', 'Upstream')), (('CSA', 'Upstream'), ('UAE', 'Upstream')), (('EAS', 'Upstream'), ('EUR', 'Upstream')), (('EAS', 'Upstream'), ('OCE', 'Upstream')), (('EAS', 'Upstream'), ('SAS', 'Upstream')), (('EAS', 'Upstream'), ('UAE', 'Upstream')), (('EUR', 'Upstream'), ('OCE', 'Upstream')), (('EUR', 'Upstream'), ('SAS', 'Upstream')), (('EUR', 'Upstream'), ('UAE', 'Upstream')), (('OCE', 'Upstream'), ('SAS', 'Upstream')), (('OCE', 'Upstream'), ('UAE', 'Upstream')), (('SAS', 'Upstream'), ('UAE', 'Upstream'))]
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# # Frequency distribution by exon

# %% [markdown]
# Lets take a closer look at our frequency distribution like before> For this set, lets separate the data into groups by exon.

# %% [markdown]
# ## within populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Exon"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [ASSIGN] filler text for any variants which do not have an exon annotation
    TMP.fillna("Non-Exon", inplace=True)

    # [ASSIGN] a numeric sorting key, constructed using the numerator in the fraction-based exon labeling system
    TMP["Exon Sorting Key"] = TMP["Exon"].str.split("/", expand=True)[0]

    # [ASSIGN] the correct numerical sorting key for non-exon mutations which did not use the fraction-based exon labeling system
    TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)

    # [ASSIGN] cast the column to a numeric type, to ensure no data-type confusion when plotting
    TMP["Exon Sorting Key"] = to_numeric(TMP["Exon Sorting Key"])

    # [SORT] the TMP DataFrame by the newly created sorting key
    TMP.sort_values(by="Exon Sorting Key", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["exon_within"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        hue_order=sorted(TMP["Exon"].unique().tolist()),
        boxprops={'edgecolor': 'none'}
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["exon_within"].get_xticks():
        PLOT[gene]["exon_within"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")

    # [ASSIGN] a list of exons to be analysed
    exons_found = TMP["Exon"].unique().tolist()

    # [PLOT] set limits on the y-axis
    PLOT[gene]["exon_within"].set(ylim=(0, 1))

    # [ASSIGN] a variable to house our tallied up filter expressions
    combinations_between_populations = list()

    # [FOR] each combination of any two consequence types possible...
    for exon_1, exon_2 in combinations(exons_found, 2):
        # [ASSIGN] a temporary variable to house all combinations for the above-two exons
        _tmp = list()

        # [FOR] each population in our list of populations to be compared
        for population in POPULATIONS_TO_COMPARE:
            # [ASSIGN] a set of comparison expressions to compare these two exons within our populations
            _tmp.extend([((population, exon_1), (population, exon_2))])

        # [ASSIGN] the filter expressions generated for the above exon-comparison across all populations into our tally variable
        combinations_between_populations.extend(_tmp)

    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["exon_within"],
        combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        order=POPULATIONS_TO_COMPARE,
        hue_order=sorted(exons_found),
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )
    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()

    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["exon_within"].axhline(1, _x_min, _x_max, c="gray", ls=":")

    # [PLOT] a label for the abovementioned horizontal line
    PLOT[gene]["exon_within"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )

    # [PLOT] a title for our plot
    PLOT[gene]["exon_within"].figure.suptitle(
        f"Distribution of allele frequencies by exon (within populations) | {gene}"
    )

    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["exon_within"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# SAS_4/8 vs. SAS_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.217e-03 U_stat=2.500e+01
# AFR_4/8 vs. AFR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.403e-02 U_stat=3.800e+01
# SAS_Non-Exon vs. SAS_4/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.119e-02 U_stat=1.704e+03
# AFR_Non-Exon vs. AFR_4/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.327e-02 U_stat=1.750e+03
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Non-Exon vs. EAS_1/1: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.653e-02 U_stat=1.248e+05
# EUR_1/1 vs. EUR_2/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.431e-02 U_stat=3.084e+03
# EUR_Non-Exon vs. EUR_2/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.523e-03 U_stat=5.925e+04
# AMR_Non-Exon vs. AMR_3/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.491e-03 U_stat=5.693e+04
# EUR_Non-Exon vs. EUR_3/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.737e-03 U_stat=5.718e+04
# EAS_2/8 vs. EAS_5/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.570e-02 U_stat=5.190e+02
# EAS_Non-Exon vs. EAS_5/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.669e-02 U_stat=2.241e+04
# /tmp/ipykernel_1008657/4203548399.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# ## between populations

# %%
# [FOR] gene in list of genes covered in this analysis
for gene in LOCATIONS_COVERED:

    # [TRANSFORM] data columns from wide-format (col = variable) to long-format (col1=variable,col2=value)
    TMP = melt(
        DATA[gene],
        id_vars=["Exon"],
        value_vars=POPULATIONS_TO_COMPARE,
        value_name="Frequency",
        var_name="Population",
    )

    # [ASSIGN] filler text for any variants which do not have an exon annotation
    TMP.fillna("Non-Exon", inplace=True)

    # [ASSIGN] a numeric sorting key, constructed using the numerator in the fraction-based exon labeling system
    TMP["Exon Sorting Key"] = TMP["Exon"].str.split("/", expand=True)[0]
    
    # [ASSIGN] the correct numerical sorting key for non-exon mutations which did not use the fraction-based exon labeling system
    TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)

    # [ASSIGN] cast the column to a numeric type, to ensure no data-type confusion when plotting
    TMP["Exon Sorting Key"] = to_numeric(TMP["Exon Sorting Key"])

    # [SORT] the TMP DataFrame by the newly created sorting key
    TMP.sort_values(by="Exon Sorting Key", inplace=True)

    # [PLOT] Init a new canvas, otherwise plots will be superimposed
    figure()

    # [PLOT] a box-plot describing frequencies, grouped by population and consequence type.
    PLOT[gene]["exon_between"] = boxplot(
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        hue_order=sorted(TMP["Exon"].unique().tolist()),
        boxprops={'edgecolor': 'none'},
        order=POPULATIONS_TO_COMPARE
    )

    # [PLOT] x-axis dividers to help make identifying the small boxes with significance annotations easier
    for x_tick in PLOT[gene]["exon_between"].get_xticks():
        PLOT[gene]["exon_between"].axvline(x_tick+.5, linestyle="--", linewidth=0.5, color="lightgrey")

    # [ASSIGN] a list of exons to be analyzed
    exons_found = TMP["Exon"].unique().tolist()

    # [PLOT] set limits on the y-axis
    PLOT[gene]["exon_between"].set(ylim=(0, 1))
    
    # [ASSIGN] a variable to house our tallied up filter expressions
    combinations_between_populations = list()
    
    # [FOR] each exon found...
    for consequence in TMP["Exon"].unique().tolist():
        _tmp = list()
        for population_1, population_2 in combinations(POPULATIONS_TO_COMPARE, 2):
            _tmp.extend([((population_1, consequence), (population_2, consequence))])
        combinations_between_populations.extend(_tmp)
    
    # [STATS] order the combinations so that the annotations wont create visual noise
    combinations_between_populations.sort(key=lambda combination: combination[0])
    
    # [STATS] Create our statistical testing interface and configure our data and plot to be used
    test_between_consequences = Annotator(
        PLOT[gene]["exon_between"],
        combinations_between_populations,
        data=TMP,
        x="Population",
        y="Frequency",
        hue="Exon",
        order=POPULATIONS_TO_COMPARE,
        hue_order=sorted(exons_found),
    )

    # [STATS] configure the statistical tests to be used, and the combinations to be tested
    test_between_consequences.configure(
        test="Mann-Whitney",
        text_format="star",
        loc="inside",
        comparisons_correction="bonferroni",
        hide_non_significant=True,
    )
    # [STATS] apply the statistics and annotate the results onto the plot
    test_between_consequences.apply_and_annotate()

    # [ASSIGN] the resultant x-axis limits to variables for downstream use
    _x_min, _x_max = xlim()
    
    # [PLOT] a horizontal line, indicating the natural limit on our graph
    PLOT[gene]["exon_between"].axhline(1, _x_min, _x_max, c="gray", ls=":")
    
    # [PLOT] a label for the aforementioned horizontal line
    PLOT[gene]["exon_between"].text(
        _x_min,
        1.01,
        c="gray",
        s="Max",
        verticalalignment="baseline",
        horizontalalignment="left",
    )
    
    # [PLOT] a title for our plot
    PLOT[gene]["exon_between"].figure.suptitle(
        f"Distribution of allele frequencies by exon (between populations) | {gene}"
    )
    
    # [PLOT] move the legend off of the graph
    move_legend(
        PLOT[gene]["exon_between"],
        "upper left",
        bbox_to_anchor=(1, 1),
    )
# Out:
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EUR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.666e-07 U_stat=3.253e+03
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.985e-02 U_stat=2.784e+03
# AFR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.156e-02 U_stat=2.810e+03
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.378e-03 U_stat=2.956e+03
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.511e-08 U_stat=8.180e+02
# AFR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.737e-05 U_stat=3.074e+03
# AMR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.852e-02 U_stat=2.838e+03
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.813e-08 U_stat=3.272e+03
# EUR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.885e-02 U_stat=1.310e+03
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.750e-04 U_stat=3.024e+03
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.056e-10 U_stat=3.431e+03
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.468e-02 U_stat=1.286e+03
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.648e-11 U_stat=3.543e+03
# AMR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.786e-02 U_stat=2.835e+03
# AFR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.283e-04 U_stat=3.062e+03
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.396e-06 U_stat=5.018e+04
# SAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.126e-03 U_stat=7.794e+04
# EUR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.723e-04 U_stat=5.340e+04
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.159e-04 U_stat=7.990e+04
# EUR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.925e-02 U_stat=5.599e+04
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.240e-04 U_stat=5.328e+04
# AMR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.514e-05 U_stat=5.208e+04
# CSA_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.462e-03 U_stat=7.766e+04
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.268e-02 U_stat=1.684e+04
# EAS_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.066e-05 U_stat=1.544e+04
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.259e-06 U_stat=2.847e+04
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.877e-03 U_stat=2.696e+04
# EAS_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.074e-05 U_stat=1.536e+04
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.684e-07 U_stat=1.419e+04
# AMR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.521e-02 U_stat=1.715e+04
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.264e-02 U_stat=2.760e+02
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.365e-04 U_stat=3.100e+02
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# CSA_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.139e-05 U_stat=7.309e+03
# AFR_Non-Exon vs. AMR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.713e-07 U_stat=7.636e+03
# SAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.455e-02 U_stat=3.538e+03
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.742e-07 U_stat=7.527e+03
# AFR_Non-Exon vs. CSA_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.568e-03 U_stat=6.782e+03
# AFR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.990e-15 U_stat=8.568e+03
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:9.182e-03 U_stat=6.774e+03
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.000e-02 U_stat=6.667e+03
# EAS_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.523e-04 U_stat=3.188e+03
# AFR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.836e-03 U_stat=6.746e+03
# AFR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:4.092e-04 U_stat=7.052e+03
# AFR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.065e-02 U_stat=6.760e+03
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# EAS_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.028e-04 U_stat=1.366e+04
# EUR_8/8 vs. OCE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.451e-02 U_stat=9.000e+01
# CSA_8/8 vs. EUR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.334e-03 U_stat=4.710e+02
# CSA_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:3.880e-13 U_stat=1.579e+04
# EUR_8/8 vs. SAS_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.542e-03 U_stat=7.600e+01
# EUR_Non-Exon vs. SAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.088e-04 U_stat=6.794e+03
# AMR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.175e-06 U_stat=1.431e+04
# EUR_8/8 vs. UAE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.407e-03 U_stat=6.400e+01
# EUR_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.062e-10 U_stat=5.230e+03
# AFR_8/8 vs. EUR_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.777e-04 U_stat=4.750e+02
# AMR_8/8 vs. OCE_8/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.104e-03 U_stat=6.500e+01
# AFR_Non-Exon vs. EUR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.492e-06 U_stat=1.422e+04
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# AFR_Non-Exon vs. AMR_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.120e-02 U_stat=1.804e+06
# EAS_2/8 vs. EUR_2/8: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:1.670e-02 U_stat=1.340e+03
# EAS_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:2.691e-04 U_stat=2.132e+06
# AMR_Non-Exon vs. EAS_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:6.802e-04 U_stat=2.126e+06
# OCE_Non-Exon vs. UAE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:8.667e-04 U_stat=1.785e+06
# CSA_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:7.851e-06 U_stat=2.155e+06
# AMR_Non-Exon vs. OCE_Non-Exon: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val:5.328e-10 U_stat=2.208e+06
# /tmp/ipykernel_1008657/1505002508.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   TMP["Exon Sorting Key"].replace("Non-Exon", 0, inplace=True)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04

# %% [markdown]
# # Export

# %%
Path(join("Graphs", "02")).mkdir(exist_ok=True)

# %%
for gene in LOCATIONS_COVERED:
    for graph in PLOT[gene].keys(): 
        PLOT[gene][graph].figure.savefig(join("Graphs", "02", f"{gene}_{graph}.jpeg"))
